# %% [markdown]
# <a href="https://colab.research.google.com/github/shivani983/computer-vision-handson/blob/main/medicinal_plant_image_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 42.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 75.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 61.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 77.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# %pwd
# Out:
# '/content'

# %%
# !unzip /content/drive/MyDrive/computervision/Herb_Identification.v3i.folder.zip -d /content/Herb_Identification
# Out:
# Archive:  /content/drive/MyDrive/computervision/Herb_Identification.v3i.folder.zip
#  extracting: /content/Herb_Identification/README.dataset.txt
#  extracting: /content/Herb_Identification/README.roboflow.txt
#    creating: /content/Herb_Identification/test/
#    creating: /content/Herb_Identification/test/Aloevera/
#  extracting: /content/Herb_Identification/test/Aloevera/aug_80_9336_png.rf.03dae38fb136497c71b514a0f5704b96.jpg
#  extracting: /content/Herb_Identification/test/Aloevera/aug_87_3480_png.rf.1c22ede0bf61b02fc2ee0ff1d46cd46b.jpg
#  extracting: /content/Herb_Identification/test/Aloevera/aug_87_512_png.rf.ba2b71933e7d0b02348b60cf09f1305e.jpg
#  extracting: /content/Herb_Identification/test/Aloevera/aug_88_2278_png.rf.70481a910a82893be215fa5a3fc77600.jpg
#  extracting: /content/Herb_Identification/test/Aloevera/aug_89_3987_png.rf.3401a8db3200c6f3808c70799b466db6.jpg
# ...

# %%
from ultralytics import YOLO

# loading classification model
model = YOLO('yolo11n-cls.pt')

#train the model
results = model.train(data = "/content/Herb_Identification",epochs = 40,imgsz = 640 )
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 5.52M/5.52M [00:00<00:00, 149MB/s]
# Ultralytics 8.3.120 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# inference
from IPython.display import Image

# %%
Image("/content/runs/classify/train/results.png",width =600)

# %%
# model trained on custom model
model = YOLO("/content/runs/classify/train/weights/best.pt")

results = model("/content/Herb_Identification/test/Ashwagandha/2200_jpg.rf.b3f201c6b9858b48452ca4521df504b3.jpg")

results[0].show()
# Out:
# image 1/1 /content/Herb_Identification/test/Ashwagandha/2200_jpg.rf.b3f201c6b9858b48452ca4521df504b3.jpg: 640x640 Ashwagandha 1.00, Amruta Balli 0.00, Ganike 0.00, Amla 0.00, Aloevera 0.00, 4.9ms
# Speed: 36.0ms preprocess, 4.9ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=600x450>

# %%
results = model("/content/Herb_Identification/test/Amla/1317_jpg.rf.75bdbb5c2d44144313df08d66f159ea3.jpg",save = True,conf = 0.5)
results[0].show()
# Out:
# image 1/1 /content/Herb_Identification/test/Amla/1317_jpg.rf.75bdbb5c2d44144313df08d66f159ea3.jpg: 640x640 Amla 1.00, Aloevera 0.00, Amruta Balli 0.00, Ganike 0.00, Ashwagandha 0.00, 9.4ms
# Speed: 28.7ms preprocess, 9.4ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/classify/predict
# <PIL.Image.Image image mode=RGB size=600x277>
